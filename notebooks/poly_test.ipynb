# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=range(1,15)
print(len(x))
y=[100,90,80,70,60,65,70,75,77,79,90,99,100,110]
print(len(y))
# Out:
# 14
# 14

# %%
plt.scatter(x,y)
plt.show()
